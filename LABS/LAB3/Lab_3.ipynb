# %% [markdown]
# # ESS 314: Lab 3

# %% [markdown]
# **For this lab, you will need to submit this .ipynb file, as well as separate plots from Questions 5a, 8, 9a, and 12a, and drawings from 7 and 9c.**

# %% [markdown]
#  ### **Plotting travel-time curves in Python**

# %% [markdown]
# 1. Imagine a source at the surface located 10 m from the first receiver, or geophone, in a 10-geophone line. The spacing between geophones is 10 m. We also know that the thickness of the layer closest to the surface is 20 m.

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.02.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 1:**
#
#
#
# > *a. For each geophone, sketch ray paths for (i) the direct wave and (ii)
# the refracted waves on the diagram above.*

# %% [markdown]
# > *b. Write code that meets the criteria below to calculate the travel-time curves for the direct and refracted waves using the above configuration.*
#
#
#
# i. Assume the velocity of layer 1 is 2000 m/s and the velocity of layer 2 is 4000 m/s.
#
#
# ii. This code should be similar to the code you wrote for Lab 2. Use vector operations, not a FOR loop, to do these calculations.
#
#
# iii. The travel-time equation for refracted waves is provided in equations 3.123-3.125 in the textbook:

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.02.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# > *c. Plot the travel-time curves on the same plot, and make sure to label axes and add a legend. Show plot below.*

# %% [markdown]
# ### **Question 2:**
# Answer the following questions about the travel time curves you created above.
#
#
# > *a. What is the slope of the direct wave curve?*
#
#
# > *b. What is the slope of the refracted wave curve?*
#
#
#
# > *c. What physical quantity can be derived from the slopes of these curves?*
#
#
#
# > *d. Why is the slope of the refracted wave curve shallower than that of the direct wave curve?*

# %% [markdown]
#  ### **Using REFRACT to create time-distance plots**
#
# Now, open REFRACT. This program produces a time-distance plot, just like the one you just created above, for a subsurface model that you define. You can also enter your own time- distance data and try to fit a model to those data. You will do both in today’s lab.

# %% [markdown]
# 1.   Open the Units menu and make sure that the following options are checked: **milliseconds (ms)**, **meters (m)**, and **m/s**. If an option listed  is not checked, select it to use that unit.
#
# 2.   When you open REFRACT, the model table window opens. At the top you can adjust the following options: the number of geophones, the shot offset (distance between the “shot”, or where the energy initiates, to
# the first geophone), and the spacing between geophones. For now, leave these as they are (the default should match the configuration used for your earlier script).
#
#
# 3. The subsurface model is shown in the table below the options. The default model is a 1-layer model. You can change the model using the **Add Layer** and Delete Layer buttons and double-click cells in the table to adjust the thickness, velocity, or dip angle of each layer. Add layers in order from top to bottom, as there is no option to reorder them once created (although you can delete a layer from the middle). Note that the bottom layer will always be considered to have infinite thickness. If you delete the bottom layer, the next layer up will change to indicate infinite thickness.

# %% [markdown]
# ### **Question 3:**
#
# > *Why do you think the program models the bottom layer to have infinite thickness? (You may have a better or more complete answer to this question after completing more of the lab.)*

# %% [markdown]
# 4. The bottom box shows the travel times that would result from your (idealized) survey. REFRACT calculates both the forward times (the times that would result if you started the survey at the left end of the geophone line) and the reverse times (the times that would result if you started the survey on the right end of geophone line). Both sets of times are needed to properly detect dipping layers.
# 5. Using the default 1-layer model, click the **Update Times and Plots** button.
# 6. To see a cross-section of your model, select **Section** in the **Window** menu.
#
# 7. Select **Plot** from the **Window** menu to open a travel time plot. Each dot on the plot shows the first arrival at the geophone located at that distance from the forward shot. The red line is the forward data (seismic waves generated near geophone 1) and the blue line is the reverse data (seismic waves generated near the highest numbered geophone).

# %% [markdown]
# ### **Question 4:**
#
#
# > *What type of wave is represented in this plot?*

# %% [markdown]
# 8. Return to the **Model Table** window, either by clicking on it or choosing **Model** from the **Window** menu. Add a layer to the model so you have a total of 2 layers. Change the thickness of the top layer (layer 1) and the velocities of both layers to
# match the configuration used in your Python plot.
#
#
# 9. Click **Update Times and Plots** to update the travel times shown at the bottom of the **Model Table** window as well as the plot in the other window. The forward curve in your updated plot should look similar to your Python plot from the beginning of this lab.

# %% [markdown]
# ### **Question 5:**
#
#
# > *a. Take a screen shot of the plot and submit it as a separate file with your lab. Below, write a brief explanation in which you identify which sections of the forward curve represent direct wave arrivals and which sections represent the first refracted wave arrivals. Briefly describe the labelling scheme you think REFRACT uses to identify line segments in these plots.*

# %% [markdown]
# Answer here

# %% [markdown]
# > *b. Describe the relative appearance of the forward and reverse curves. Are they symmetric or not?*

# %% [markdown]
# Answer here

# %% [markdown]
# > *c. Calculate the critical refraction angle for this model using equation 3.108 in the
# textbook. Show your work!*

# %% [markdown]
# ![Screen Shot 2021-10-14 at 7.53.45 PM.png](data:image/png;base64,...)

# %%
# Answer here

# %% [markdown]
# 11. The kink in this graph occurs when the refracted wave first starts arriving before the direct wave. The horizontal coordinate for this point is called the crossover distance.

# %% [markdown]
# ### **Question 6:**
#
#
# > *a. Calculate the crossover distance using the time travel equations for the direct
# and refracted waves. Please show your work. Does your calculation agree with the plot?*

# %%
# Answer here

# %% [markdown]
# > *b. If you decrease the layer thickness by a factor of 2 (i.e., from 20 m to 10 m), by what factor does the crossover distance change?*

# %%
# Answer here

# %% [markdown]
# ### **Question 7:**
#
#
# > *On the cross section below, illustrate (i) the critical angle and (ii) the
# crossover distance by drawing ray paths and showing angles. Make sure to pick the correct geophone at which the crossover occurs in your drawing. Take a picture of this and insert it into your document with answers to the questions in this lab.*

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.02.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# 14. Add another layer to your model. Make layers 1 10 m thick with 2000 m/s velocity and layer 2 10m thick with 3000 m/s velocity. **Update Times and Plots**.

# %% [markdown]
# ### **Question 8:**
#
# *Submit a screen shot of your updated plot from step #14 above to Canvas. How many line segments are in each curve? Identify the arrival represented by each segment of both forward and reverse curves, referring to the labels added by REFRACT.*

# %% [markdown]
# Answer here

# %% [markdown]
# 15. Now we are going to make the model a little more complicated. Change the model to use 40 stations with 10 m spacing. Revise the model to have the following layers:

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.07.02 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 9:**
#
#
#
#
#
#
# > a. Click **Update Times and Plots**. How many sections are there in the forward curve? Recall that it only includes first arrivals. Submit to Canvas a screen shot of your plot and discuss below which arrival each section of the graph represents.

# %% [markdown]
# Answer here

# %% [markdown]
# > *b. Calculate the critical refraction angle for the wave that refracts at the interface
# between the first and second layer. What is your result? Why does the section representing the wave critically refracted by layer 2 disappear?*

# %%
# Answer here

# %% [markdown]
# > *c. Using the cross section for this model (you can either use a screen shot of the
# cross section in REFRACT or redraw it yourself), draw ray paths to demonstrate why layer 2 doesn't show up in the time travel plot. Submit this to Canvas.*

# %% [markdown]
# 17. We have just identified a problem with the seismic refraction method: refracted waves do not propagate through a low-velocity layer! As a result, we cannot determine the wave speed or thickness of a low-velocity layer. This highlights the importance of using multiple methods in geophysical studies. As you'll learn next week, low velocity layers can be detected with a reflection study.

# %% [markdown]
#  ### **Dipping Layers**
#
# We are going to explore one more thing: dipping layers.
#
# 1. Create a new 2-layer model with 10 geophones and 10 m spacing. Layer 1 should have 10 m thickness, velocity 4000 m/s, and a 3° angle. Layer 2 should have velocity 8000 m/s and no dip angle. Since this is the bottom layer, the thickness will be infinite. **Update Times and Plots.**
#
# 2. Look at the cross section for this model in REFRACT to understand how thickness and dip angle work together in this program. Experiment a bit with different thicknesses and angles until you feel confident that you know how to interpret and model a dipping layer. Be sure to return to the model configuration in the previous step before you answer any questions.

# %% [markdown]
# ### **Question 10:**
#
#
#
# > *What do you notice about the forward and reverse time-distance curves? How does this compare to what you saw in Question 5?*

# %% [markdown]
# Answer here

# %% [markdown]
# 4. Because the base of layer 1 is dipping away from the end of the geophone line, layer 1 is thicker at the beginning of the geophone line and thinner at the end of the geophone line. This affects the relative timing of the forward and reverse refracted waves and creates the anti-symmetry in the results.
# 5. In the **Plot Window**, hover the cursor over a portion of the curve and look at the lower left corner of the window. This reports the apparent velocity (**App. Vel.**) of each layer, as well as the intercept time (**Interc.**; the time axis intercept) for the layer indicated by the label.
# 6. Review the velocities for the direct wave sections (**1F** and **1R**) of the curves. The velocities reported for these curves are exactly as given in the model for layer 1.

# %% [markdown]
# 7. Now hover over the curves F2 and R2 to get the apparent velocities of the forward and reverse experiments. These apparent velocities are the inverses of the slopes of the travel-time curves. In the next two equations, symbols have the following meanings (see figure 3.72 and equations 3.138 and 3.139 in the textbook).
#
#
#
# > a. v1 is the velocity of the top layer
#
#
# > b. v2 is the velocity of the second layer
#
#
# > c. v2u is the apparent velocity for layer 2 according to the waves travelling up-dip d.
#
# > d. v2d is the apparent velocity for layer 2 according to the waves travelling down- dip
#
#
# > e. Beta is the dip
#
#
# > f. Theta(ic) is the critical angle for layer 2

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.19.56 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 11:**
#
#
# *Note: In accordance with the way angles are typically reported in this course, be sure to use the degree version of trig functions in the provided formulas.*
#
# *Note: Use variables to represent all the known quantities (the three velocities). Do all of your actual calculations using the variables – don't just plug the numbers directly into the formulas. Comment your code so I know what each variable means.*
#
# > *Use the expressions above to write a script below to calculate the dip and velocity of layer 2.*

# %%
# Answer here

# %% [markdown]
# > *What values does your script produce for (i) dip, (ii) critical angle, and (iii) the velocity of the second layer?*

# %%
# Answer here

# %% [markdown]
# ### **Analyzing the Ledgewood Landslide**
#
# Okay, now for the fun part! We are going to explore a real problem.
#
# Many of you may have heard of the Ledgewood Landslide that happened on Whidbey Island on March 27, 2013. Almost 200,000 yd3 (40,000 dump truck loads) of dirt slipped down the hillside. While the slide area for the Ledgewood Landslide only extends about 400-500 meters across the hillside, the entire coastline is a giant landslide scarp, where similar landslides have been happening for the last 10,000 years.

# %% [markdown]
# ![APTOPIX_Washington_Landslide-2040x1265.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Ledgewood Landslide, March 2013.** Photo by Ted S. Warren / The Associated Press

# %% [markdown]
# Why is this coastline so susceptible to landslides? There are a few reasons. One is that the ocean erodes away at the base of the hillside making it unstable. Additionally, lots of rain tends to saturate the soil, making it weaker. Another reason has to do with the types of layers in the shallow subsurface. At the base of the hill there is a glacial clay layer. This layer sits under layers of other, coarser glacial deposits. Water can flow through the coarser glacial deposits, but gets trapped above the clay layer, creating an ideal slide plane.
#
#
# To assess landslide risk, we are going to use seismic refraction to map the top of the clay layer. Somebody already went out and collected the data for us. They set out 50 geophones, spaced 20 meters apart, on the top of the bluff, which is 120 meters higher than the beach. The first geophone is farthest away from the edge and the last geophone is right on the edge of the bluff (see figure below).
#
# ![Screen Shot 2021-10-14 at 8.28.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# 1. Download the file WhidbeyData.txt from your JupyterHub. Open the file and take a quick look at its contents (but be sure not to change anything).
#
#
# > a. This is a csv (comma-separated values) file with some configuration information at the top and then a bunch of data.
#
#
#
# > b. Take note of the information in the first four lines – you will need this to set up your model in REFRACT.'
#
#
#
#
# 2. Open REFRACT and make sure your time units are milliseconds. Close any open **Plot** or **Section** windows.
#
# 3. From REFRACT's **File** menu, open the WhidbeyData.txt file.
#
#
#
#
# > a. REFRACT can interpret the configuration information at the beginning of this file.
# When you open the file, it will ask you if you want to change current model configuration to what is shown in the data file. When asked, agree to make the model consistent with the data. If you accidentally click No, you can also change the values manually in the Model Table.
#
#
#
# > b. The data file will open in a new window, which you can get back to using the **Data** option of the **Window** menu.
#
#
#
# > c. Don't do anything in the Model window for now (i.e, don't click on the Update times and plots button).

# %% [markdown]
# 4. Open the Plot window.
#
#
#
#
# > a. The legend at the top shows that the data points are plotted as triangles, while
# times based on the current Model layers are shown with circles.
#
#
# > b. Note the color coding of forward versus reverse data.

# %% [markdown]
# 5. We're going to use this data to develop a model for the subsurface on this cliff. The first step is to guess the number of layers. Each layer should be represented by a straight- line segment on the data plot.
#
#
#
#
# > a. Add the appropriate number layers in the **Model** window. For now, don't worry about thicknesses, velocities, or dips – just accept the default values for those quantities.
#
#
#
# > b. Click **Update Times and Plots** to reflect your new model in the Plot window.

# %% [markdown]
# 6. Back in the **Plot** window, click and drag the calculated forward line segments around to fit the data points. This process can be tricky and will likely take you multiple tries. It is probably best to drag the segment corresponding to the bottom-most layer into place first, then proceed towards the top.
#
#
#
# > a. To drag an entire line segment up /down or left /right, click and drag the label close to the relevant part of the data points.
#
#
#
#
# > b. To change the angle or length of a line segment, click and drag the black squares at the end of the line.
#
#
#
# > c. Recall that it's just the slope of each segment that matters, so don't worry too much about aligning the end points. In fact, it'll be a lot easier to manipulate the line segments if you make them longer than the data points, so you can see that they properly cover the triangles without the black squares at the end getting in your way.
#
#
# 7. Once you're satisfied with the correspondence between data and calculations for your forward time-distance curve, repeat the previous step for the reverse curve.
#
#
#
#
# > a. At first glance, the number of layers in the reverse shot data is more subtle. However, once you start fitting the calculated lines to the triangles, it'll become more obvious that the reverse data has the same number of layers as the forward data.
#
#
#
#
# 8. Back in the **Model** window, click **Model from Plot**. This will update the calculated time travel curves on the plot and in the table in the **Model** window.
#
#
# 9. Return to the **Plot** window and see how well the circles (calculated values) correspond with the triangles (observations). Iterate on this process until you are satisfied with your model. Don't forget to always click the **Model from Plot** button in the **Model** window after moving lines around on the plot.
#
#
# 10) View your cross section using the **Section** option on the **Window** menu.

# %% [markdown]
# ### **Question 12:**
#
#
#
# > *a. Take a screen shot of the resulting cross section and upload it to Canvas. Add a caption below indicating the orientation of the cross- section relative to the beach.*

# %% [markdown]
# Answer here

# %% [markdown]
# > *b. Imagine you're a geologist reporting on the structure of this bluff to the Island County Council. Write a paragraph describing the shallow subsurface based on your model, following the guidelines outlined below. This question is open- ended, so be creative – but make sure your answer is physically possible.*

# %% [markdown]
# Answer below

# %% [markdown]
# ![Screen Shot 2021-10-14 at 8.39.19 PM.png](data:image/png;base64,...)
